# %% [markdown]
# # Chicago Public Schools - Progress Report Cards (2011-2012)
#
# Dataset page: https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t
#
# Dataset csv: https://data.cityofchicago.org/resource/9xs2-f89t.csv
#
# Types of metrics in the database: https://data.cityofchicago.org/api/assets/AAD41A13-BE8A-4E67-B1F5-86E711E09D5F?download=true

# %% [markdown]
# **QUESTIONS**
# 1. How many Elementary Schools are in the dataset?
# 2. Which schools have highest Safety Score?
# 3. What are the top 10 schools with the highest "Average Student Attendance"?
# 4. Retrieve the list of 5 Schools with the lowest Average Student Attendance sorted in ascending order based on attendance
# 5. Now remove the '%' sign from the above result set for Average Student Attendance column
# 6. Which Schools have Average Student Attendance lower than 70%?
# 7. Get the total College Enrollment for each Community Area
# 8. Get the 5 Community Areas with the least total College Enrollment sorted in ascending order
# 9. List 5 schools with lowest safety score
# 10. Get the hardship index for the community area of the school which has College Enrollment of 4368
# 11. Get the hardship index for the community area which has the highest value for College Enrollment

# %%
import sqlite3

conn = sqlite3.connect('ChicagoPS.db')

# %%
# %load_ext sql 

# %sql sqlite:///ChicagoPS.db

# %% [markdown]
# Retrieve data to the database

# %%
import pandas as pd

df = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv')
df.to_sql('Chicago', conn, if_exists='replace')
# Out:
# 566

# %% [markdown]
# To see all the tables in the database

# %%
# %sql SELECT name FROM sqlite_master WHERE type = 'table'
# Out:
#  * sqlite:///ChicagoPS.db
# Done.
# [('Chicago',)]

# %%
# %sql SELECT * FROM Chicago LIMIT 5
# Out:
#  * sqlite:///ChicagoPS.db
# Done.
# [(0, 610038, 'Abraham Lincoln Elementary School', 'ES', '615 W Kemper Pl', 'Chicago', 'IL', 60614, '(773) 534-5720', 'http://schoolreports.cps.edu/SchoolProgressReport_Eng/Spring2011Eng_610038.pdf', 'Fullerton Elementary Network', 'NORTH-NORTHWEST SIDE COLLABORATIVE', 'No', 'Standard', 'Not on Probation', 'Level 1', 'Yes', 'Very Strong', 99.0, 'Very Strong', '99', 'Strong', 74.0, 'Strong', 66.0, 'Weak', '65', 'Strong', '70', 'Strong', '56', 'Average', '47', '96.00%', 2.0, '96.40%', '95.80%', '80.1', '43.3', '89.6', '84.9', '60.7', '62.6', '81.9', '85.2', '52', '62.4', '66.3', '77.9', 69.7, 64.4, 0.2, 0.9, 'Yellow', 'Green', '67.1', '54.5', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 813, 33, 'NDA', 1171699.458, 1915829.428, 41.92449696, -87.64452163, 7, 'LINCOLN PARK', 43, 18, '(41.92449696, -87.64452163)'),
# ...
